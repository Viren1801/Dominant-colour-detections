# %%
import cv2
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("examples/img_2.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
cluster = KMeans(n_clusters=5)
cluster.fit(img.reshape(-1,3))
# Out:
# KMeans(n_clusters=5)

# %%
cluster.cluster_centers_
# Out:
# array([[195.058636  , 195.71737543, 194.94874214],
#        [ 18.80963764,  22.46312987,  23.1848612 ],
#        [ 85.53119697,  88.71904013,  90.89209594],
#        [142.29558856,  49.97412099,  49.01762706],
#        [152.6567789 , 127.97091939, 126.60915089]])

# %%
arr = cluster.cluster_centers_

# %%
arr
# Out:
# array([[195.058636  , 195.71737543, 194.94874214],
#        [ 18.80963764,  22.46312987,  23.1848612 ],
#        [ 85.53119697,  88.71904013,  90.89209594],
#        [142.29558856,  49.97412099,  49.01762706],
#        [152.6567789 , 127.97091939, 126.60915089]])

# %%
def show_dominant_colors(arr):
    color_deck = np.zeros((50, 300, 3), dtype= np.uint8)
    steps = 300 / arr.shape[0]
    for idx, ele in enumerate(arr):
        color_deck[:, int(idx*steps):(int((idx+1)*steps)), :] = ele
    return color_deck

# %%
plt.imshow(show_dominant_colors(arr))
